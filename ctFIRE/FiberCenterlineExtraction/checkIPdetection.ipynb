# %%
import IPdetection
dataPath ='H:\\GitHub.06.2022\\AnalysisTools\\testImages\\ctFIREout\\ctFIREout_synSize512-fiber100.mat'
imagePath= 'H:\\GitHub.06.2022\\AnalysisTools\\testImages\\synSize512-fiber100.tif'
# coordPath = 'IPyx_skeleton.mat'
IPyx = IPdetection.IP_skeleton(dataPath,imagePath)

# %%
import os
imageName = os.path.basename(imagePath)
dirOut  = os.path.dirname(dataPath)
imageNoExt,ext = os.path.splitext(imageName)
coordPath = os.path.join(dirOut,'IPxy_skeleton_'+imageNoExt+'.mat')
print(dirOut)
print(coordPath)
# Out:
# H:\GitHub.06.2022\AnalysisTools\testImages\ctFIREout
# H:\GitHub.06.2022\AnalysisTools\testImages\ctFIREout\IPxy_skeleton_synSize512-fiber100.mat
