# %%
import deepcell_seg
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import deepcell_seg
#
# File H:\GitHub.06.2022\curvelets\src\CurveAlign_CT-FIRE\Cellanalysis\WholeCell\deepcell_seg.py:2
#       1 from skimage.io import imread, imsave
# ----> 2 from deepcell.applications import CytoplasmSegmentation, Mesmer
#       3 import numpy as np
#       4 import scipy.io as sio
#
# File ~\.conda\envs\pyDC310\lib\site-packages\deepcell\__init__.py:31
#      26 """Package for single cell image segmentation with convolutional neural networks"""
#      29 from deepcell._version import __version__
# ---> 31 from deepcell import applications
#      32 from deepcell import callbacks
#      33 from deepcell import datasets
#
# File ~\.conda\envs\pyDC310\lib\site-packages\deepcell\applications\__init__.py:30
#      26 """Deepcell Applications - Pre-trained models for specific functions"""
#      29 from deepcell.applications.application import Application
# ---> 30 from deepcell.applications.cytoplasm_segmentation import CytoplasmSegmentation
#      31 from deepcell.applications.mesmer import Mesmer
#      32 from deepcell.applications.multiplex_segmentation import MultiplexSegmentation
#
# File ~\.conda\envs\pyDC310\lib\site-packages\deepcell\applications\cytoplasm_segmentation.py:31
#      26 """Cytoplasmic segmentation application"""
#      29 import os
# ---> 31 import tensorflow as tf
#      33 from deepcell_toolbox.processing import histogram_normalization
#      34 from deepcell_toolbox.deep_watershed import deep_watershed
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\__init__.py:48
#      45 from tensorflow.python import tf2 as _tf2
#      46 _tf2.enable()
# ---> 48 from tensorflow._api.v2 import __internal__
#      49 from tensorflow._api.v2 import __operators__
#      50 from tensorflow._api.v2 import audio
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\__internal__\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\__internal__\autograph\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.autograph namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert # line: 493
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\autograph\core\ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\autograph\utils\__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\autograph\utils\context_managers.py:19
#      15 """Various context managers."""
#      17 import contextlib
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:29
#      26 from absl import app
#      27 import numpy as np
# ---> 29 from tensorflow.core.framework import attr_value_pb2
#      30 from tensorflow.core.framework import full_type_pb2
#      31 from tensorflow.core.framework import function_pb2
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\core\framework\attr_value_pb2.py:5
#       1 # -*- coding: utf-8 -*-
#       2 # Generated by the protocol buffer compiler.  DO NOT EDIT!
#       3 # source: tensorflow/core/framework/attr_value.proto
#       4 """Generated protocol buffer code."""
# ----> 5 from google.protobuf.internal import builder as _builder
#       6 from google.protobuf import descriptor as _descriptor
#       7 from google.protobuf import descriptor_pool as _descriptor_pool
#
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (C:\Users\liu372\.conda\envs\pyDC310\lib\site-packages\google\protobuf\internal\__init__.py)

# %%
from skimage.io import imread
from deepcell.applications import CytoplasmSegmentation
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from skimage.io import imread
# ----> 2 from deepcell.applications import CytoplasmSegmentation
#       3 import numpy as np
#
# File ~\.conda\envs\pyDC310\lib\site-packages\deepcell\__init__.py:31
#      26 """Package for single cell image segmentation with convolutional neural networks"""
#      29 from deepcell._version import __version__
# ---> 31 from deepcell import applications
#      32 from deepcell import callbacks
#      33 from deepcell import datasets
#
# File ~\.conda\envs\pyDC310\lib\site-packages\deepcell\applications\__init__.py:30
#      26 """Deepcell Applications - Pre-trained models for specific functions"""
#      29 from deepcell.applications.application import Application
# ---> 30 from deepcell.applications.cytoplasm_segmentation import CytoplasmSegmentation
#      31 from deepcell.applications.mesmer import Mesmer
#      32 from deepcell.applications.multiplex_segmentation import MultiplexSegmentation
#
# File ~\.conda\envs\pyDC310\lib\site-packages\deepcell\applications\cytoplasm_segmentation.py:31
#      26 """Cytoplasmic segmentation application"""
#      29 import os
# ---> 31 import tensorflow as tf
#      33 from deepcell_toolbox.processing import histogram_normalization
#      34 from deepcell_toolbox.deep_watershed import deep_watershed
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\__init__.py:48
#      45 from tensorflow.python import tf2 as _tf2
#      46 _tf2.enable()
# ---> 48 from tensorflow._api.v2 import __internal__
#      49 from tensorflow._api.v2 import __operators__
#      50 from tensorflow._api.v2 import audio
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\__internal__\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\__internal__\autograph\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.autograph namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert # line: 493
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\autograph\core\ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\autograph\utils\__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\autograph\utils\context_managers.py:19
#      15 """Various context managers."""
#      17 import contextlib
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:29
#      26 from absl import app
#      27 import numpy as np
# ---> 29 from tensorflow.core.framework import attr_value_pb2
#      30 from tensorflow.core.framework import full_type_pb2
#      31 from tensorflow.core.framework import function_pb2
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\core\framework\attr_value_pb2.py:5
#       1 # -*- coding: utf-8 -*-
#       2 # Generated by the protocol buffer compiler.  DO NOT EDIT!
#       3 # source: tensorflow/core/framework/attr_value.proto
#       4 """Generated protocol buffer code."""
# ----> 5 from google.protobuf.internal import builder as _builder
#       6 from google.protobuf import descriptor as _descriptor
#       7 from google.protobuf import descriptor_pool as _descriptor_pool
#
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (C:\Users\liu372\.conda\envs\pyDC310\lib\site-packages\google\protobuf\internal\__init__.py)

# %%
# Load the image
im = imread('tests/F01_366w1_copy.tif')

# Expand image dimensions to rank 4
im = np.expand_dims(im, axis=-1)
im = np.expand_dims(im, axis=0)

# Create the application
app = CytoplasmSegmentation()

# create the lab
labeled_image = app.predict(im)
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# print(labeled_image.shape)
# from PIL import Image
# result = Image.fromarray(labeled_image)
# result.save('test.tif')
labeled_image_reshape = labeled_image[0,:,:,0]
print(labeled_image_reshape.shape)
from PIL import Image
result = Image.fromarray(labeled_image_reshape)
result.save('F01_366w1_copy_mesmer.tif')
# Out:
# (1040, 1392)
