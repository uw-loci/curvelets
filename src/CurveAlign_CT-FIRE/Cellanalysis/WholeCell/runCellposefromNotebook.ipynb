# %%
#import cellpose_seg
import deepcell_seg

# %%
# image_path = 'H:\\GitHub.06.2022\\curvelets\\Cellanalysis\\WholeCell\\fluorescence_C1.tif'
# image_path = 'H:\\GitHub.06.2022\\AnalysisTools\\caTest\\Cell_fluo\\CTtest1.tif'
image_path = 'CFtest1.tif'
# cp_mask = cellpose_seg.cyto_seg(image_path,'nuclei')
dp_mask = deepcell_seg.cyto_seg(image_path,'cyto',1)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
import numpy as np
dp_mask.shape
dcSQ = np.squeeze(dp_mask)
dcSQ.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 import numpy as np
# ----> 2 dp_mask.shape
#       3 dcSQ = np.squeeze(dp_mask)
#       4 dcSQ.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# show the results
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import numpy as np
plt.title('1-channel fluorescence image')
plt.xlabel("Image Width")
plt.ylabel("Image Height")
I1 = mpimg.imread(image_path)


fig, axs = plt.subplots(1,2,figsize=(6,6))
axs[0].imshow(I1),plt.title('cellpose image')

axs[1].imshow(dcSQ),plt.title('deepcell mask')
plt.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.2, hspace=0.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 15
#      12 fig, axs = plt.subplots(1,2,figsize=(6,6))
#      13 axs[0].imshow(I1),plt.title('cellpose image')
# ---> 15 axs[1].imshow(dcSQ),plt.title('deepcell mask')
#      16 plt.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.2, hspace=0.4)
#
# File c:\Users\liu372\.conda\envs\DC2py311\lib\site-packages\matplotlib\__init__.py:1501, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1498 @functools.wraps(func)
#    1499 def inner(ax, *args, data=None, **kwargs):
#    1500     if data is None:
# -> 1501         return func(
#    1502             ax,
#    1503             *map(sanitize_sequence, args),
#    1504             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1506     bound = new_sig.bind(ax, *args, **kwargs)
# ...

# %%
import deepcell_seg
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import deepcell_seg
#
# File H:\GitHub.06.2022\curvelets\Cellanalysis\WholeCell\deepcell_seg.py:2
#       1 from skimage.io import imread, imsave
# ----> 2 from deepcell.applications import CytoplasmSegmentation, Mesmer
#       3 import numpy as np
#       4 import scipy.io as sio
#
# File ~\.conda\envs\CApy310\lib\site-packages\deepcell\__init__.py:31
#      26 """Package for single cell image segmentation with convolutional neural networks"""
#      29 from deepcell._version import __version__
# ---> 31 from deepcell import applications
#      32 from deepcell import callbacks
#      33 from deepcell import datasets
#
# File ~\.conda\envs\CApy310\lib\site-packages\deepcell\applications\__init__.py:30
#      26 """Deepcell Applications - Pre-trained models for specific functions"""
# ...
